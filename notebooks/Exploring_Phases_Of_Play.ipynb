# %%
import pandas as pd

base_directory = 'C:/Users/navee/OneDrive/Documents/SkillCorner_Tracking_Data_Project/data/matches'

df = pd.read_csv(f"{base_directory}/1886347/1886347_phases_of_play.csv")

# %%
df
# Out:
#      index  match_id  frame_start  frame_end time_start time_end  \
# 0        0   1886347           28         89    00:01.8  00:07.9
# 1        1   1886347           89        107    00:07.9  00:09.7
# 2        2   1886347          185        232    00:17.5  00:22.2
# 3        3   1886347          232        283    00:22.2  00:27.3
# 4        4   1886347          283        301    00:27.3  00:29.1
# ..     ...       ...          ...        ...        ...      ...
# 449    449   1886347        58293      58310    95:49.3  95:51.0
# 450    450   1886347        58310      58413    95:51.0  96:01.3
# 451    451   1886347        58413      58614    96:01.3  96:21.4
# 452    452   1886347        58705      58771    96:30.5  96:37.1
# 453    453   1886347        58771      58932    96:37.1  96:53.2
#
#      minute_start  second_start  duration  period  ...        third_end  \
# 0               0             1       6.1       1  ...     middle_third
# ...

# %%
df['team_in_possession_phase_type'].value_counts()
# Out:
# team_in_possession_phase_type
# create         156
# chaotic         97
# finish          89
# build_up        63
# direct          23
# set_play        20
# transition       3
# quick_break      3
# Name: count, dtype: int64

# %%
df['team_out_of_possession_phase_type'].value_counts()
# Out:
# team_out_of_possession_phase_type
# medium_block             156
# chaotic                   97
# low_block                 89
# high_block                63
# defending_direct          23
# defending_set_play        20
# defending_transition       3
# defending_quick_break      3
# Name: count, dtype: int64
