# %%
import pandas as pd

df = pd.read_csv("C:/Users/navee/OneDrive/Documents/SkillCorner_Tracking_Data_Project/data/aggregates/aus1league_physicalaggregates_20242025_midfielders.csv")

# %% [markdown]
# Opponent has the ball - otip.
#
# Team has the ball - tip.

# %%
df
# Out:
#                  player_name player_short_name  player_id player_birthdate  \
# 0               Adam Taggart        A. Taggart        211       1993-06-02
# 1               Adama Traoré         A. Traoré        218       1990-02-03
# 2            Dino Arslanagić     D. Arslanagić       2759       1993-04-24
# 3    Douglas  Costa de Souza     Douglas Costa       2858       1990-09-14
# 4    Douglas  Costa de Souza     Douglas Costa       2858       1990-09-14
# ..                       ...               ...        ...              ...
# 401         Fabian Talladira      F. Talladira     973078       2006-02-04
# 402        Kyle Reilly  Shaw           K. Shaw     998256       2004-09-07
# 403            Austin Ludwik         A. Ludwik     998558       1997-02-11
# 404           Harry Crawford       H. Crawford     998842       1991-12-10
# 405           Harry Crawford       H. Crawford    1002177       2007-02-03
#
#                            team_name  team_id competition_name  \
# ...
